# %%
import json
from collections import defaultdict
import pandas as pd

# %%
with open("output/professor_map.json", "r") as f:
    professor_map = json.load(f)

# %%
all_professor_names = set()
name_map = {}
for name, authors in professor_map.items():
    for author in authors:
        for dblp_name in author.get("author", []):
            all_professor_names.add(dblp_name)
            name_map[dblp_name] = name

# %%
import argparse
import html
import json
import xml.sax
import xml.sax.saxutils
from collections import defaultdict
from pathlib import Path


class PublicationFilter(xml.sax.saxutils.XMLFilterBase):
    def __init__(self, name_map, all_professor_names, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.stack = [None]
        self.attrs = []
        self.name_map = name_map
        self.all_professor_names = all_professor_names
        self.publications = defaultdict(list)
        self.text_active = []
        self.current = None
        self.count = 0

    def startElement(self, name, attrs):
        self.stack.append(name)
        if name == "www" and self.stack[-1] is None:
            pass # Ignore
        elif self.current is None:
            # all top level that are not www may be a work that we should consider
            self.current = defaultdict(list)
            self.current["_name"] = name
            self.current["_attrs"] = dict(attrs.items())
        elif self.current is not None:
            self.text_active.append([])
            self.attrs.append(dict(attrs.items()))

    def endElement(self, name):
        if name == "www":
            pass
        elif name == self.stack[-1] == self.current["_name"]: 
            intersection = set(self.current.get("author", set())) & self.all_professor_names 
            for professor in intersection:
                self.publications[self.name_map[professor]].append(self.current)
                self.count += 1
                if self.count < 20:
                    print(self.current)
            self.current = None
        elif self.current:
            key = name
            atribs = self.attrs.pop()
            value = html.unescape("".join(self.text_active.pop()))
            self.current[key].append(value)
            self.current[f"{key}-attrs"].append(atribs)
        self.stack.pop()
        

    def characters(self, content):
        if self.text_active:
            self.text_active[-1].append(content)

    def skippedEntity(self, name):
        if self.text_active:
            self.text_active[-1].append(f"&{name};")

# %%
parser = xml.sax.make_parser()
reader = PublicationFilter(name_map, all_professor_names, parser)
reader.parse("input/dblp.xml")

# %%
reader.publications
# Out:
# defaultdict(list, {})

# %%
professor_map = defaultdict(list)
for pid, author in pid_map.items():
    for name in author.get('author', []):
        if name in professors:
            professor_map[name].append(author)

# %%
skip_prompt = False
no = False
force_load = False
load_manual = "input/manual_map.csv"
missing = set(professors) - set(professor_map)
while (missing and not no) or force_load:
    if not skip_prompt:
        print(f"{len(missing)} professor not found:")
        for professor in missing:
            print(f"- {professor}")
        answer = input(f"Do you want to load map from '{load_manual}? [Y,n,other]").strip()
    else:
        answer = 'y'
    skip_prompt = False
    if answer and answer.lower()[0] == 'n':
        break
    if answer and answer.lower()[0] == 'o':
        new_file = input(f"Which file do you want to load? Leave it in blank to go back").strip()
        if new_file:
            load_manual = new_file
            answer = 'y'
    if not answer or answer.lower()[0] in ('y', 's'):
        df = pd.read_csv(load_manual)
        for i, row in df.iterrows():
            if row["professor"] in missing:
                professor_map[row["professor"]].append(pid_map[row["pid"]])
        missing = set(professors) - set(professor_map)
        force_load = False

if missing:
    print(f"WARNING: creating map without {len(missing)} professors:")
    for professor in missing:
        print(f"- {professor}")

# %%
professor_map
# Out:
# defaultdict(list,
#             {'Aline Marins Paes Carvalho': [{'pid': '95/4928',
#                'author': ['Aline Paes',
#                 'Aline Marins Paes',
#                 'Aline Marins Paes Carvalho'],
#                'affiliation': ['Fluminense Federal University, Brazil'],
#                'url': ['http://www2.ic.uff.br/~alinepaes/',
#                 'https://orcid.org/0000-0002-9089-7303'],
#                'orcid': ['0000-0002-9089-7303']}],
#              'Aura Conci': [{'pid': 'c/AuraConci',
#                'author': ['Aura Conci'],
#                'affiliation': ['Fluminense Federal University, Brazil'],
#                'url': ['http://www.ic.uff.br/~aconci/',
#                 'https://orcid.org/0000-0003-0782-2501',
#                 'https://www.wikidata.org/entity/Q58727483'],
#                'orcid': ['0000-0003-0782-2501']}],
#              'Taiane Coelho Ramos': [{'pid': '352/3463',
#                'author': ['Taiane Coelho Ramos']}],
#              'Troy Costa Kohwalter': [{'pid': '123/3298',
#                'author': ['Troy C. Kohwalter', 'Troy Costa Kohwalter'],
#                'url': ['https://orcid.org/0000-0002-5183-473X',
#                 'https://www.wikidata.org/entity/Q60870700'],
#                'orcid': ['0000-0002-5183-473X']}],
#              'Ricardo Leiderman': [{'pid': '203/3036',
#                'author': ['Ricardo Leiderman']}],
#              'Mariza Ferro': [{'pid': '09/10314',
#                'author': ['Mariza Ferro'],
#                'url': ['https://orcid.org/0000-0003-0191-582X'],
#                'orcid': ['0000-0003-0191-582X']}],
#              'Vanessa Braganholo Murta': [{'pid': '84/2055',
#                'author': ['Vanessa Braganholo',
#                 'Vanessa Braganholo Murta',
#                 'Vanessa P. Braganholo',
#                 'Vanessa de Paula Braganholo'],
#                'url': ['http://www.ic.uff.br/~vanessa',
#                 'https://dl.acm.org/profile/81318497412',
#                 'https://orcid.org/0000-0002-1184-8192',
#                 'http://lattes.cnpq.br/0060120644445370'],
#                'orcid': ['0000-0002-1184-8192'],
#                'affiliation': ['Fluminense Federal University, Niterói, Brazil',
#                 'University of Rio de Janeiro (UFRJ), Computer Science Department']}],
#              'Mario Roberto Folhadela Benevides': [{'pid': '29/5198',
#                'author': ['Mario R. F. Benevides',
#                 'Mario Roberto Folhadela Benevides'],
#                'affiliation': ['Federal University of Rio de Janeiro, Brazil'],
#                'url': ['https://orcid.org/0000-0002-1481-1942',
#                 'https://www.wikidata.org/entity/Q59553952'],
#                'orcid': ['0000-0002-1481-1942']}],
#              'André Maués Brabo Pereira': [{'pid': '28/7852',
#                'author': ['André Maués Brabo Pereira']}],
#              'Fábio Protti': [{'pid': '61/2851',
#                'author': ['Fábio Protti'],
#                'affiliation': ['Fluminense Federal University, Brazil'],
#                'url': ['http://www.ic.uff.br/~fabio/',
#                 'https://orcid.org/0000-0001-9924-0079'],
#                'orcid': ['0000-0001-9924-0079']}],
#              'Milton Brown Do Coutto Filho': [{'pid': '184/9663',
#                'author': ['Milton Brown Do Coutto Filho']}],
#              'Julio Cesar Stacchini de Souza': [{'pid': '184/9658',
#                'author': ['Julio Cesar Stacchini de Souza']}],
#              'Yuri Abitbol de Menezes Frota': [{'pid': '304/9105',
#                'author': ['Yuri Abitbol de Menezes Frota']}],
#              'João Felipe Nicolaci Pimentel': [{'pid': '161/7127',
#                'author': ['João Felipe Pimentel',
#                 'João Felipe N. Pimentel',
#                 'João Felipe Nicolaci Pimentel'],
#                'url': ['https://orcid.org/0000-0001-6680-7470'],
#                'orcid': ['0000-0001-6680-7470']}],
#              'Daniela Gorski Trevisan': [{'pid': 't/DanielaGorskiTrevisan',
#                'author': ['Daniela Gorski Trevisan',
#                 'Daniela G. Trevisan',
#                 'Daniela Trevisan 0001'],
#                'affiliation': ['Fluminense Federal University, Institute of Computing, Niterói, Brazil'],
#                'url': ['http://www.tele.ucl.ac.be/view-people.php?id=129',
#                 'https://orcid.org/0000-0003-0061-4689'],
#                'orcid': ['0000-0003-0061-4689']}],
#              'Bruno Lopes Vieira': [{'pid': '187/9712',
#                'author': ['Bruno Lopes 0001', 'Bruno Lopes Vieira'],
#                'affiliation': ['Fluminense Federal University, Rio de Janeiro, Brazil',
#                 'Pontifical Catholic University of Rio de Janeiro, Brazil'],
#                'url': ['http://www.ic.uff.br/~bruno/',
#                 'https://scholar.google.com/citations?user=iWm5AjYAAAAJ',
#                 'https://mathgenealogy.org/id.php?id=182595',
#                 'https://orcid.org/0000-0003-1204-0176'],
#                'orcid': ['0000-0003-1204-0176']}],
#              'Luiz Satoru Ochi': [{'pid': 'o/LuizSatoruOchi',
#                'author': ['Luiz Satoru Ochi', 'Luiz S. Ochi'],
#                'affiliation': ['Fluminense Federal University, Brazil'],
#                'url': ['http://www.ic.uff.br/~satoru/',
#                 'https://orcid.org/0000-0002-5007-4513',
#                 'https://www.wikidata.org/entity/Q86725859',
#                 'https://d-nb.info/gnd/1122991770'],
#                'orcid': ['0000-0002-5007-4513']}],
#              'Célio Vinicius Neves de Albuquerque': [{'pid': '40/809',
#                'author': ['Célio Vinicius N. de Albuquerque',
#                 'Célio Vinicius Neves de Albuquerque',
#                 'Célio Vinicius N. Albuquerque',
#                 'Célio Albuquerque 0001'],
#                'url': ['https://orcid.org/0000-0002-7959-6569'],
#                'orcid': ['0000-0002-7959-6569'],
#                'affiliation': ['Universidade Federal Fluminense, Niteroi, RJ, Brazil']}],
#              'Raphael Carlos Santos Machado': [{'pid': '83/1163',
#                'author': ['Raphael Machado',
#                 'Raphael C. S. Machado',
#                 'Raphael Carlos Santos Machado']}],
#              'Luiz André Portes Paes Leme': [{'pid': '75/6273',
#                'author': ['Luiz André P. Paes Leme',
#                 'Luiz André Portes Paes Leme'],
#                'affiliation': ['Fluminense Federal University, Brazil'],
#                'url': ['http://www.ic.uff.br/~lapaesleme',
#                 'https://orcid.org/0000-0001-6014-7256'],
#                'orcid': ['0000-0001-6014-7256']}],
#              'Leonardo Gresta Paulino Murta': [{'pid': '25/3645',
#                'author': ['Leonardo Murta 0001',
#                 'Leonardo G. P. Murta',
#                 'Leonardo Gresta Paulino Murta'],
#                'affiliation': ['Fluminense Federal University, Institute of Computing'],
#                'url': ['http://www2.ic.uff.br/~leomurta/',
#                 'https://scholar.google.com/citations?user=VEbJeB8AAAAJ',
#                 'https://dl.acm.org/profile/81325489653',
#                 'https://orcid.org/0000-0002-5173-1247',
#                 'http://lattes.cnpq.br/1565296529736448',
#                 'https://ieeexplore.ieee.org/author/37303836200'],
#                'orcid': ['0000-0002-5173-1247']}],
#              'Daniel Cardoso Moraes de Oliveira': [{'pid': '68/7553-1',
#                'author': ['Daniel de Oliveira 0001',
#                 'Daniel C. M. de Oliveira',
#                 'Daniel Cardoso Moraes de Oliveira',
#                 'Daniel Oliveira 0001'],
#                'affiliation': ['Fluminense Federal University (UFF), Institute of Computing, Niterói, RJ, Brazil',
#                 'Federal University of Rio de Janeiro (UFRJ), Rio de Janeiro, RJ, Brazil'],
#                'archive': ['http://www.ic.uff.br/~danielcmo'],
#                'url': ['https://www.youtube.com/@danielcardosomoraesdeolive8682',
#                 'https://scholar.google.com/citations?user=T_YePXEAAAAJ',
#                 'https://orcid.org/0000-0001-9346-7651',
#                 'https://www.wikidata.org/entity/Q96148276',
#                 'https://d-nb.info/gnd/1192516095',
#                 'http://lattes.cnpq.br/0743793296062293'],
#                'orcid': ['0000-0001-9346-7651']}],
#              'Lúcia Maria de Assumpção Drummond': [{'pid': '41/2824',
#                'author': ['Lúcia M. A. Drummond',
#                 'Lúcia Maria de A. Drummond',
#                 'Lúcia Maria de Assumpção Drummond'],
#                'affiliation': ['Fluminense Federal University (UFF), Institute of Computing, Niterói, Brazil'],
#                'url': ['http://pesquisadores.uff.br/researcher/l%C3%BAcia-maria-de-assump%C3%A7%C3%A3o-drummond',
#                 'https://scholar.google.com/citations?user=UhYdnvYAAAAJ',
#                 'https://orcid.org/0000-0002-3831-5230'],
#                'orcid': ['0000-0002-3831-5230']}],
#              'Vânia de Oliveira Neves': [{'pid': '156/1942',
#                'author': ['Vânia de Oliveira Neves', 'Vânia Neves'],
#                'url': ['http://profs.ic.uff.br/~vania/',
#                 'https://scholar.google.com/citations?user=_54c69IAAAAJ',
#                 'https://orcid.org/0000-0003-4648-2263'],
#                'orcid': ['0000-0003-4648-2263']}],
#              'José Viterbo Filho': [{'pid': '15/374',
#                'author': ['José Viterbo', 'José Viterbo Filho'],
#                'url': ['http://www.ic.uff.br/index.php/en-GB/pessoas/168-docente?docente=36',
#                 'https://scholar.google.com/citations?user=twAYAPsAAAAJ',
#                 'https://orcid.org/0000-0002-0339-6624',
#                 'https://www.wikidata.org/entity/Q57415314',
#                 'http://lattes.cnpq.br/8721187139726277'],
#                'orcid': ['0000-0002-0339-6624'],
#                'affiliation': ['Fluminense Federal University, Niterói, Brazil']}],
#              'Luciana Cardoso de Castro Salgado': [{'pid': '15/7693',
#                'author': ['Luciana Cardoso de Castro Salgado',
#                 'Luciana C. de C. Salgado',
#                 'Luciana Salgado'],
#                'url': ['https://scholar.google.com/citations?user=exVgvFgAAAAJ',
#                 'https://orcid.org/0000-0003-1207-6021'],
#                'orcid': ['0000-0003-1207-6021'],
#                'affiliation': ['Universidade Federal Fluminense']}],
#              'Leandro Santiago de Araújo': [{'pid': '230/3564',
#                'author': ['Leandro Santiago de Araújo',
#                 'Leandro Santiago 0001'],
#                'affiliation': ['Federal University of Rio de Janeiro, Brazil'],
#                'url': ['https://orcid.org/0000-0002-3631-8761'],
#                'orcid': ['0000-0002-3631-8761']}],
#              'Flávio Luiz Seixas': [{'pid': '66/4837',
#                'author': ['Flávio Luiz Seixas']}],
#              'Esteban Walter Gonzalez Clua': [{'pid': '59/5772',
#                'author': ['Esteban Walter Gonzalez Clua',
#                 'Esteban Walter Clua',
#                 'Esteban Clua',
#                 'Esteban W. G. Clua'],
#                'affiliation': ['Universidade Federal, Fluminense (UFF), Niterói, Brazil'],
#                'url': ['https://orcid.org/0000-0001-5650-1718',
#                 'https://www.wikidata.org/entity/Q91488227'],
#                'orcid': ['0000-0001-5650-1718']}],
#              'Paulo de Figueiredo Pires': [{'pid': '69/1904',
#                'author': ['Paulo F. Pires', 'Paulo de Figueiredo Pires'],
#                'affiliation': ['Federal University of Rio de Janeiro, Brazil'],
#                'url': ['https://orcid.org/0000-0001-5064-4793',
#                 'https://www.wikidata.org/entity/Q56882618'],
#                'orcid': ['0000-0001-5064-4793']}],
#              'Igor Monteiro Moraes': [{'pid': '32/6032',
#                'author': ['Igor M. Moraes', 'Igor Monteiro Moraes']}],
#              'Simone de Lima Martins': [{'pid': '50/11138',
#                'author': ['Simone de Lima Martins']}],
#              'Leandro Augusto Frata Fernandes': [{'pid': '48/5542',
#                'author': ['Leandro A. F. Fernandes',
#                 'Leandro Augusto Frata Fernandes'],
#                'url': ['https://orcid.org/0000-0001-8491-793X',
#                 'https://www.wikidata.org/entity/Q54274951'],
#                'orcid': ['0000-0001-8491-793X']}],
#              'Uéverton dos Santos Souza': [{'pid': '48/11143',
#                'author': ['Uéverton S. Souza', 'Uéverton dos Santos Souza'],
#                'affiliation': ['Fluminense Federal University, Brazil'],
#                'url': ['http://www2.ic.uff.br/~ueverton/',
#                 'https://mathgenealogy.org/id.php?id=197045',
#                 'https://orcid.org/0000-0002-5320-9209'],
#                'orcid': ['0000-0002-5320-9209']}],
#              'Maria Cristina Silva Boeres': [{'pid': '89/6061',
#                'author': ['Cristina Boeres', 'Maria Cristina Silva Boeres'],
#                'affiliation': ['Universidade Federal Fluminense, Niterói, Brazil'],
#                'url': ['https://sites.google.com/a/ic.uff.br/cristina-boeres/',
#                 'https://scholar.google.com/citations?user=h_AmAEYAAAAJ',
#                 'http://lattes.cnpq.br/0306766365983082',
#                 'https://ieeexplore.ieee.org/author/37266667700']}],
#              'Igor Machado Coelho': [{'pid': '89/8466',
#                'author': ['Igor Machado Coelho'],
#                'url': ['https://scholar.google.com/citations?user=EDOt1VIAAAAJ',
#                 'https://orcid.org/0000-0001-6373-4907'],
#                'orcid': ['0000-0001-6373-4907'],
#                'affiliation': ['Universidade do Estado do Rio de Janeiro']}],
#              'Luis Antonio Brasil Kowada': [{'pid': '54/4829',
#                'author': ['Luis Antonio Brasil Kowada'],
#                'url': ['http://www.professores.uff.br/kowada/']}],
#              'Anselmo Antunes Montenegro': [{'pid': '21/6489',
#                'author': ['Anselmo Antunes Montenegro'],
#                'url': ['https://orcid.org/0000-0001-9342-8732'],
#                'orcid': ['0000-0001-9342-8732']}],
#              'Antônio Augusto de Aragão Rocha': [{'pid': '209/2422',
#                'author': ['Antônio Augusto de Aragão Rocha',
#                 'Antônio A. de A. Rocha']}],
#              'Flávia Coimbra Delicato': [{'pid': '88/4289',
#                'author': ['Flávia Coimbra Delicato'],
#                'url': ['https://orcid.org/0000-0001-5334-8279'],
#                'orcid': ['0000-0001-5334-8279']}],
#              'Flávia Cristina Bernardini': [{'pid': '88/5413',
#                'author': ['Flavia Bernardini',
#                 'Flávia Bernardini',
#                 'Flávia Cristina Bernardini'],
#                'url': ['https://www.professores.uff.br/fcbernardini/',
#                 'https://scholar.google.com/citations?user=bdAatn0AAAAJ',
#                 'https://orcid.org/0000-0001-8801-827X',
#                 'https://www.wikidata.org/entity/Q58727357'],
#                'orcid': ['0000-0001-8801-827X']}],
#              'Alexandre Plastino de Carvalho': [{'pid': '54/401',
#                'author': ['Alexandre Plastino 0001',
#                 'Alexandre P. de Carvalho 0001'],
#                'affiliation': ['Fluminense Federal University, Niterói, Rio de Janeiro, Brazil'],
#                'url': ['http://www.dcc.ic.uff.br/~plastino/',
#                 'https://scholar.google.com/citations?user=axlvTZoAAAAJ',
#                 'https://orcid.org/0000-0003-4039-0915',
#                 'http://lattes.cnpq.br/4985266524417261'],
#                'orcid': ['0000-0003-4039-0915']}],
#              'Celso da Cruz Carneiro Ribeiro': [{'pid': '26/4167',
#                'author': ['Celso C. Ribeiro'],
#                'url': ['http://www2.ic.uff.br/~celso/',
#                 'https://scholar.google.com/citations?user=yGl1MwgAAAAJ',
#                 'https://orcid.org/0000-0002-9478-2351'],
#                'orcid': ['0000-0002-9478-2351'],
#                'affiliation': ['Universidade Federal Fluminense, Brazil']}],
#              'Diego Gimenez Passos': [{'pid': '47/4581',
#                'author': ['Diego G. Passos 0001', 'Diego Gimenez Passos 0001'],
#                'url': ['https://orcid.org/0000-0002-9707-1176',
#                 'http://lattes.cnpq.br/4380871234657190'],
#                'orcid': ['0000-0002-9707-1176'],
#                'affiliation': ['Federal Fluminense University, Brasil']}],
#              'Débora Christina Muchaluat Saade': [{'pid': '21/5891',
#                'author': ['Débora C. Muchaluat-Saade',
#                 'Débora Christina Muchaluat-Saade',
#                 'Débora C. Muchaluat']}],
#              'Eugene Francis Vinod Rebello': [{'pid': '79/2476',
#                'author': ['Vinod E. F. Rebello']}],
#              'Isabel Cristina Mello Rosseti': [{'pid': '42/6628',
#                'author': ['Isabel Rosseti'],
#                'url': ['https://orcid.org/0000-0001-8560-5313'],
#                'orcid': ['0000-0001-8560-5313']}],
#              'Luís Felipe Ignácio Cunha': [{'pid': '117/3901',
#                'author': ['Luís Felipe I. Cunha']}],
#              'Marcos Vinícius Naves Bêdo': [{'pid': '133/1121',
#                'author': ['Marcos V. N. Bedo', 'Marcos Vinicius Naves Bedo'],
#                'affiliation': ['Fluminense Northwest Institute, INFES/UFF, Brazil']}],
#              'Marcos de Oliveira Lage Ferreira': [{'pid': '46/4560',
#                'author': ['Marcos Lage'],
#                'url': ['https://orcid.org/0000-0003-3868-8886',
#                 'https://www.wikidata.org/entity/Q88823356'],
#                'orcid': ['0000-0003-3868-8886']}],
#              'Pedro Cortez Fetter Lopes': [{'pid': '306/6510',
#                'author': ['Pedro C. Lopes']}]})

# %%
df = pd.read_csv(load_manual)

# %%
# Out:
# professor    Alexandre Plastino de Carvalho
# pid                                  54/401
# Name: 0, dtype: object
# professor    Celso da Cruz Carneiro Ribeiro
# pid                                 26/4167
# Name: 1, dtype: object
# professor    Diego Gimenez Passos
# pid                       47/4581
# Name: 2, dtype: object
# professor    Débora Christina Muchaluat Saade
# pid                                   21/5891
# Name: 3, dtype: object
# professor    Eugene Francis Vinod Rebello
# pid                               79/2476
# Name: 4, dtype: object
# professor    Isabel Cristina Mello Rosseti
# pid                                42/6628
# Name: 5, dtype: object
# professor    Luís Felipe Ignácio Cunha
# pid                           117/3901
# Name: 6, dtype: object
# professor    Marcos Vinícius Naves Bêdo
# pid                            133/1121
# Name: 7, dtype: object
# professor    Marcos de Oliveira Lage Ferreira
# pid                                   46/4560
# Name: 8, dtype: object
# professor    Pedro Cortez Fetter Lopes
# pid                           306/6510
# Name: 9, dtype: object

# %%
keys = set()
count = 0
for value in reader.pid_map.values():
    if value.get('deprecated', '') != '' and count < 10:
        count += 1
        print(value)
    keys |= set(value.keys())
# Out:
# defaultdict(<class 'list'>, {'pid': '157/1995', 'author': ['Alireza Khalili Golmankhaneh', 'Ali Khalili Golmankhaneh', 'Ali K. Golmankhaneh'], 'affiliation': ['Islamic Azad University, Urmia, Iran'], 'url': ['https://orcid.org/0000-0002-5008-0163', 'https://www.wikidata.org/entity/Q63148849'], 'deprecated': ['https://orcid.org/0000-0002-3490-7976']})
# defaultdict(<class 'list'>, {'pid': '63/2223-2', 'author': ['Yimin Zhou 0002', 'Yi-Min Zhou 0002'], 'affiliation': ['Chengdu University of Information Technology, School of Cybersecurity, China', 'University of Electronic Science and Technology of China, School of Computer Science and Engineering, Chengdu, China'], 'url': ['https://orcid.org/0000-0001-8692-9635', 'https://ieeexplore.ieee.org/author/37399624300'], 'deprecated': ['https://orcid.org/0000-0002-6539-0316']})
# defaultdict(<class 'list'>, {'pid': '63/8189', 'author': ['Xue-Yang Zhu', 'Xueyang Zhu'], 'url': ['http://lcs.ios.ac.cn/~zxy/', 'https://dl.acm.org/profile/81472645829', 'https://orcid.org/0000-0002-2832-5590'], 'deprecated': ['https://orcid.org/0000-0002-4708-768X'], 'affiliation': ['Chinese Academy of Sciences, Institute of Software, Beijing, China'], 'uname': ['朱雪阳']})
# defaultdict(<class 'list'>, {'pid': 'y/MotiYung', 'author': ['Moti Yung', 'Mordechai M. Yung'], 'affiliation': ['Google Inc., New York, NY, USA', 'Columbia University, New York City, USA'], 'url': ['http://www1.cs.columbia.edu/~moti/', 'https://scholar.google.com/citations?user=ScL8iFQAAAAJ', 'https://dl.acm.org/profile/81452601790', 'https://zbmath.org/authors/?q=ai:yung.moti', 'https://mathscinet.ams.org/mathscinet/MRAuthorID/246521', 'https://mathgenealogy.org/id.php?id=61951', 'https://en.wikipedia.org/wiki/Moti_Yung', 'https://orcid.org/0000-0003-0848-0873', 'https://www.wikidata.org/entity/Q6917668', 'https://id.loc.gov/authorities/names/nb2002091844', 'https://d-nb.info/gnd/1228382794'], 'deprecated': ['https://scholar.google.com/citations?user=DPlvOL4AAAAJ']})
# defaultdict(<class 'list'>, {'pid': 'y/PingkunYan', 'author': ['Pingkun Yan'], 'affiliation': ['Rensselaer Polytechnic Institute, Department of Biomedical Engineering, Troy, NY, USA', 'University of Central Florida, Orlando, USA', 'National University of Singapore, Singapore'], 'note': ['Philips Research North America, Bethesda, MD, USA'], 'url': ['https://faculty.rpi.edu/node/36177', 'https://scholar.google.com/citations?user=qkIp7AEAAAAJ', 'https://orcid.org/0000-0002-9779-2141', 'https://www.wikidata.org/entity/Q47106990', 'https://www.researchgate.net/profile/Pingkun_Yan'], 'deprecated': ['https://orcid.org/0000-0001-7473-6334']})
# defaultdict(<class 'list'>, {'pid': '216/0781', 'author': ['Dalei Hao'], 'url': ['https://orcid.org/0000-0003-3497-9774', 'https://www.wikidata.org/entity/Q91858012'], 'deprecated': ['https://orcid.org/0000-0001-7154-6332']})
# defaultdict(<class 'list'>, {'pid': '95/4452-2', 'author': ['Haoran Zhang 0002'], 'affiliation': ['LocationMind Inc., Chiyoda-ku, Japan', 'Peking University, School of Urban Planning and Design, Beijing, China', 'China University of Petroleum, Beijing, China'], 'note': ['University of Tokyo, Japan'], 'url': ['https://orcid.org/0000-0002-4641-0641', 'https://www.scopus.com/authid/detail.uri?authorId=57204578013', 'https://ieeexplore.ieee.org/author/37086364576'], 'deprecated': ['https://orcid.org/0000-0001-5745-6939', 'https://orcid.org/0000-0001-9602-8646']})
# defaultdict(<class 'list'>, {'pid': '95/8433-1', 'author': ['Hongyang Li 0001'], 'affiliation': ['University of Hong Kong', 'Shanghai AI Laboratory, China', 'University of California at San Diego, USA'], 'url': ['https://lihongyang.info/', 'https://orcid.org/0000-0001-9110-5534'], 'deprecated': ['https://orcid.org/0000-0001-9446-6191']})
# defaultdict(<class 'list'>, {'pid': '95/8558', 'author': ['Faramarz Mehrnejad'], 'affiliation': ['University of Tehran, Iran', 'Azarbaijan Shahid Madani University, Tabriz, Iran'], 'url': ['http://fnst.ut.ac.ir/en/~mehrnejad', 'https://orcid.org/0000-0002-2991-3079', 'https://www.wikidata.org/entity/Q59691984', 'https://www.wikidata.org/entity/Q89372571', 'https://www.scopus.com/authid/detail.uri?authorId=16309961300', 'https://www.scopus.com/authid/detail.uri?authorId=57201272090', 'https://www.researchgate.net/profile/Faramarz_Mehrnejad'], 'deprecated': ['https://orcid.org/0000-0002-4444-6990']})
# defaultdict(<class 'list'>, {'pid': '95/4042', 'author': ['André Soares 0001', 'André C. B. Soares', 'André Castelo Branco Soares'], 'affiliation': ['Federal University of Piaui (UFPI), Teresina, PI, Brazil'], 'url': ['https://www.sigaa.ufpi.br/sigaa/public/docente/portal.jsf?siape=1632612', 'https://orcid.org/0000-0002-3909-8610', 'https://www.wikidata.org/entity/Q98619874', 'http://lattes.cnpq.br/4545154317245176'], 'deprecated': ['https://orcid.org/0000-0001-9109-2366']})

# %%
keys
# Out:
# {'affiliation',
#  'archive',
#  'author',
#  'award',
#  'cite',
#  'crossref',
#  'deprecated',
#  'former',
#  'isnot',
#  'note',
#  'pid',
#  'uname',
#  'url'}

# %%
set(reader.professors) - set(reader.professors_map)
# Out:
# {'Alexandre Plastino de Carvalho',
#  'Celso da Cruz Carneiro Ribeiro',
#  'Diego Gimenez Passos',
#  'Débora Christina Muchaluat Saade',
#  'Eugene Francis Vinod Rebello',
#  'Isabel Cristina Mello Rosseti',
#  'Luís Felipe Ignácio Cunha',
#  'Marcos Vinícius Naves Bêdo',
#  'Marcos de Oliveira Lage Ferreira',
#  'Pedro Cortez Fetter Lopes'}

# %%
reader.professors_map
# Out:
# defaultdict(list,
#             {'Aline Marins Paes Carvalho': ['95/4928'],
#              'Aura Conci': ['c/AuraConci'],
#              'Taiane Coelho Ramos': ['352/3463'],
#              'Troy Costa Kohwalter': ['123/3298'],
#              'Ricardo Leiderman': ['203/3036'],
#              'Mariza Ferro': ['09/10314'],
#              'Vanessa Braganholo Murta': ['84/2055'],
#              'Mario Roberto Folhadela Benevides': ['29/5198'],
#              'André Maués Brabo Pereira': ['28/7852'],
#              'Fábio Protti': ['61/2851'],
#              'Milton Brown Do Coutto Filho': ['184/9663'],
#              'Julio Cesar Stacchini de Souza': ['184/9658'],
#              'Yuri Abitbol de Menezes Frota': ['304/9105'],
#              'João Felipe Nicolaci Pimentel': ['161/7127'],
#              'Daniela Gorski Trevisan': ['t/DanielaGorskiTrevisan'],
#              'Bruno Lopes Vieira': ['187/9712'],
#              'Luiz Satoru Ochi': ['o/LuizSatoruOchi'],
#              'Célio Vinicius Neves de Albuquerque': ['40/809'],
#              'Raphael Carlos Santos Machado': ['83/1163'],
#              'Luiz André Portes Paes Leme': ['75/6273'],
#              'Leonardo Gresta Paulino Murta': ['25/3645'],
#              'Daniel Cardoso Moraes de Oliveira': ['68/7553-1'],
#              'Lúcia Maria de Assumpção Drummond': ['41/2824'],
#              'Vânia de Oliveira Neves': ['156/1942'],
#              'José Viterbo Filho': ['15/374'],
#              'Luciana Cardoso de Castro Salgado': ['15/7693'],
#              'Leandro Santiago de Araújo': ['230/3564'],
#              'Flávio Luiz Seixas': ['66/4837'],
#              'Esteban Walter Gonzalez Clua': ['59/5772'],
#              'Paulo de Figueiredo Pires': ['69/1904'],
#              'Igor Monteiro Moraes': ['32/6032'],
#              'Simone de Lima Martins': ['50/11138'],
#              'Leandro Augusto Frata Fernandes': ['48/5542'],
#              'Uéverton dos Santos Souza': ['48/11143'],
#              'Maria Cristina Silva Boeres': ['89/6061'],
#              'Igor Machado Coelho': ['89/8466'],
#              'Luis Antonio Brasil Kowada': ['54/4829'],
#              'Anselmo Antunes Montenegro': ['21/6489'],
#              'Antônio Augusto de Aragão Rocha': ['209/2422'],
#              'Flávia Coimbra Delicato': ['88/4289'],
#              'Flávia Cristina Bernardini': ['88/5413']})

# %%
from xml.sax.saxutils import unescape
html.unescape('Jo&aacute;o Felipe Nicolaci Pimentel')
# Out:
# 'Joáo Felipe Nicolaci Pimentel'
